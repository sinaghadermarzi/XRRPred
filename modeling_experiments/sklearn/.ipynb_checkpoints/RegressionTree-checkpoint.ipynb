# %% [markdown]
# Regression Tree
# ---------
# Here we test regression tree on the dataset. This model doesn't need feature selection because it internally selects features.

# %%
import json
with open("configurations.json") as jsonfile:
    jj = json.load(jsonfile)

# %%
jj
# Out:
# {'dataset_root_dir': '/home/ghadermarzis/ExpanDrive/Google Drive/VCU_PhD_Research/Work/XRC_Resolution/repo/redoing/dataset/',
#  'target_vars': ['resolution', 'rfree'],
#  'sampling_methods': ['impover1',
#   'impover2',
#   'smote1',
#   'smote2',
#   'und1',
#   'und2'],
#  'file_locations': {'training_set': {'nosampling': {'resolution': 'original/training_set.csv',
#     'rfree': 'original/training_set.csv'},
#    'impover1': {'resolution': 'sampled/res_training_impover1.csv',
#     'rfree': 'sampled/rfree_training_impover1.csv'},
#    'impover2': {'resolution': 'sampled/res_training_impover2.csv',
#     'rfree': 'sampled/rfree_training_impover2.csv'},
#    'smote1': {'resolution': 'sampled/res_training_smote1.csv',
#     'rfree': 'sampled/rfree_training_smote1.csv'},
#    'smote2': {'resolution': 'sampled/res_training_smote2.csv',
#     'rfree': 'sampled/rfree_training_smote2.csv'},
#    'und1': {'resolution': 'sampled/res_training_und1.csv',
# ...
